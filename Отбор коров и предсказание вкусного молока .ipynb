# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект:-Линейные-модели-в-машинном-обучении" data-toc-modified-id="Проект:-Линейные-модели-в-машинном-обучении-1">Проект: Линейные модели в машинном обучении</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1">Описание проекта</a></span></li><li><span><a href="#Шаг-1.-Загрузка-данных" data-toc-modified-id="Шаг-1.-Загрузка-данных-1.2">Шаг 1. Загрузка данных</a></span></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-1.3">Шаг 2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-данных-на-наличие-пропусков-и-дубликатов" data-toc-modified-id="Проверка-данных-на-наличие-пропусков-и-дубликатов-1.3.1">Проверка данных на наличие пропусков и дубликатов</a></span></li><li><span><a href="#Изучение-и-изменение-типа-данных" data-toc-modified-id="Изучение-и-изменение-типа-данных-1.3.2">Изучение и изменение типа данных</a></span></li><li><span><a href="#Изучение-категориальных-признаков" data-toc-modified-id="Изучение-категориальных-признаков-1.3.3">Изучение категориальных признаков</a></span><ul class="toc-item"><li><span><a href="#Изучение-категориальных-признаков-ferma_main" data-toc-modified-id="Изучение-категориальных-признаков-ferma_main-1.3.3.1">Изучение категориальных признаков ferma_main</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-3.--Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.--Исследовательский-анализ-данных-1.4">Шаг 3.  Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Статистический-анализ-количественных-признаков" data-toc-modified-id="Статистический-анализ-количественных-признаков-1.4.0.1">Статистический анализ количественных признаков</a></span></li><li><span><a href="#Статистический-анализ-категориальных-признаков" data-toc-modified-id="Статистический-анализ-категориальных-признаков-1.4.0.2">Статистический анализ категориальных признаков</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-4.--Корреляционный-анализ-ferma_main" data-toc-modified-id="Шаг-4.--Корреляционный-анализ-ferma_main-1.5">Шаг 4.  Корреляционный анализ ferma_main</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Взаимосвязь-между-признаками--коэффициенты-корреляции" data-toc-modified-id="Взаимосвязь-между-признаками--коэффициенты-корреляции-1.5.0.1">Взаимосвязь между признаками -коэффициенты корреляции</a></span></li><li><span><a href="#Диаграммы-рассеяния-для-количественных-признаков" data-toc-modified-id="Диаграммы-рассеяния-для-количественных-признаков-1.5.0.2">Диаграммы рассеяния для количественных признаков</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-5.--Обучение-модели-линейной-регрессии" data-toc-modified-id="Шаг-5.--Обучение-модели-линейной-регрессии-1.6">Шаг 5.  Обучение модели линейной регрессии</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Первая-модель-LinearRegression" data-toc-modified-id="Первая-модель-LinearRegression-1.6.0.1">Первая модель LinearRegression</a></span></li><li><span><a href="#Вторая-модель-LinearRegression" data-toc-modified-id="Вторая-модель-LinearRegression-1.6.0.2">Вторая модель LinearRegression</a></span></li><li><span><a href="#Третья-модель-LinearRegression-(новый-признак)" data-toc-modified-id="Третья-модель-LinearRegression-(новый-признак)-1.6.0.3">Третья модель LinearRegression (новый признак)</a></span></li><li><span><a href="#Качество-моделей-линейной-регрессии,-их-R²-и-остатки." data-toc-modified-id="Качество-моделей-линейной-регрессии,-их-R²-и-остатки.-1.6.0.4">Качество моделей линейной регрессии, их R² и остатки.</a></span></li><li><span><a href="#MSE,-MAE,-RMSE" data-toc-modified-id="MSE,-MAE,-RMSE-1.6.0.5">MSE, MAE, RMSE</a></span></li><li><span><a href="#Прогноз-удоя-по-лучшей-модели" data-toc-modified-id="Прогноз-удоя-по-лучшей-модели-1.6.0.6">Прогноз удоя по лучшей модели</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-6.--Обучение-модели-логистической-регрессии" data-toc-modified-id="Шаг-6.--Обучение-модели-логистической-регрессии-1.7">Шаг 6.  Обучение модели логистической регрессии</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Обучение-логистической-модели" data-toc-modified-id="Обучение-логистической-модели-1.7.0.1">Обучение логистической модели</a></span></li><li><span><a href="#Анализ-логистической-модели" data-toc-modified-id="Анализ-логистической-модели-1.7.0.2">Анализ логистической модели</a></span></li><li><span><a href="#Прогноз-вкуса-молока-коров" data-toc-modified-id="Прогноз-вкуса-молока-коров-1.7.0.3">Прогноз вкуса молока коров</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-7.--Итоговые-выводы" data-toc-modified-id="Шаг-7.--Итоговые-выводы-1.8">Шаг 7.  Итоговые выводы</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Отбор-коров,-для-которых-спрогнозирован-удой-более-6000-килограммов-в-год-и-вкусное-молоко." data-toc-modified-id="Отбор-коров,-для-которых-спрогнозирован-удой-более-6000-килограммов-в-год-и-вкусное-молоко.-1.8.0.1">Отбор коров, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко.</a></span></li><li><span><a href="#Результаты-работы-моделей-для-фермера" data-toc-modified-id="Результаты-работы-моделей-для-фермера-1.8.0.2">Результаты работы моделей для фермера</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Проект: Линейные модели в машинном обучении

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы работаете в IT-компании, которая выполняет на заказ проекты по машинному обучению. К вам обратился фермер, владелец молочного хозяйства «Вольный луг». Он хочет купить бурёнок, чтобы расширить поголовье стада коров. Для этого он заключил выгодный контракт с ассоциацией пастбищ «ЭкоФерма».
# Условия позволяют фермеру очень тщательно отобрать коров. Он определяет качество молока по строгой методике, и при этом ему нужно выполнять свой план развития молочного хозяйства. Фермер хочет, чтобы каждая бурёнка давала не менее 6000 килограммов молока в год, а её надой был вкусным — строго по его критериям, ничуть не хуже. А продавцы и технологи так и норовят приукрасить своих коровок!
# Поэтому он просит вас разработать модель машинного обучения, которая поможет ему управлять рисками и принимать объективное решение о покупке. «ЭкоФерма» готова предоставить подробные данные о своих коровах.
# Вам нужно создать две прогнозные модели для отбора бурёнок в поголовье:
# 1. Первая будет прогнозировать возможный удой коровы (целевой признак Удой);
# 2. Вторая — рассчитывать вероятность получить вкусное молоко от коровы (целевой признак Вкус молока).
# С помощью модели нужно отобрать коров по двум критериям:
# * средний удой за год — не менее 6000 килограммов;
# * молоко должно быть вкусным.

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import seaborn as sns
from scipy.stats import spearmanr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,   
    r2_score, accuracy_score, 
    confusion_matrix, 
    recall_score, 
    precision_score
)
from sklearn.multiclass import OneVsRestClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
# функция вывода информации о данных
def data_info(data):
    display(data.head(20))
    display(data.info())
    display(data.describe())

# %%
ferma_main = pd.read_csv('/datasets/ferma_main.csv', sep = ';', decimal = ',')

# %%
ferma_dad = pd.read_csv('/datasets/ferma_dad.csv', sep = ';', decimal = ',')

# %%
cow_buy = pd.read_csv('/datasets/cow_buy.csv', sep = ';', decimal = ',')

# %%
data_info(ferma_main)
# Out:
#     id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0    1      5863                                   14.2              1743
# 1    2      5529                                   12.8              2138
# 2    3      5810                                   14.0              1854
# 3    4      5895                                   12.4              2012
# 4    5      5302                                   12.8              1675
# 5    6      5254                                   12.7              1806
# 6    7      5910                                   13.2              1792
# 7    8      6179                                   14.7              1806
# 8    9      6783                                   14.2              1918
# 9   10      5339                                   13.4              1791
# 10  11      5591                                   13.7              1678
# 11  12      6563                                   16.5              2328
# ...

# %%
data_info(ferma_dad)
# Out:
#     id  Имя Папы
# 0    1    Буйный
# 1    2  Соловчик
# 2    3     Барин
# 3    4    Буйный
# 4    5     Барин
# 5    6     Барин
# 6    7  Соловчик
# 7    8  Геркулес
# 8    9    Буйный
# 9   10     Барин
# 10  11    Буйный
# 11  12  Соловчик
# 12  13     Барин
# 13  14    Буйный
# 14  15  Геркулес
# 15  16    Буйный
# 16  17    Буйный
# 17  18    Буйный
# 18  19  Соловчик
# 19  20     Барин
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   Имя Папы  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB
# None
#               id
# count  629.00000
# mean   315.00000
# std    181.72094
# min      1.00000
# 25%    158.00000
# 50%    315.00000
# 75%    472.00000
# max    629.00000

# %%
data_info(cow_buy)
# Out:
#              Порода Тип пастбища порода папы_быка  Имя_папы  \
# 0    Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 1    Вис Бик Айдиал    равнинное          Соверин    Буйный
# 2   РефлешнСоверинг    равнинное          Соверин     Барин
# 3   РефлешнСоверинг    холмистое           Айдиал    Буйный
# 4   РефлешнСоверинг    равнинное           Айдиал    Буйный
# 5   РефлешнСоверинг    равнинное          Соверин  Геркулес
# 6    Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 7    Вис Бик Айдиал    равнинное          Соверин    Буйный
# 8   РефлешнСоверинг    равнинное          Соверин     Барин
# 9   РефлешнСоверинг    холмистое           Айдиал    Буйный
# 10   Вис Бик Айдиал    холмистое          Соверин  Соловчик
# 11  РефлешнСоверинг    равнинное          Соверин  Геркулес
# 12   Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 13   Вис Бик Айдиал    холмистое          Соверин     Барин
# 14  РефлешнСоверинг    равнинное          Соверин     Барин
# ...

# %% [markdown]
# В ходе 1 этапа выгружены и выведены 3 датафрейма - ferma_main, ferma_dad, cow_buy. В первом и третьих датафреймах присутствуют как категориальные, так и количественные признаки, во втором ferma_dad только один столбец- Имя Папы.

# %% [markdown]
# ##  Шаг 2. Предобработка данных

# %% [markdown]
# ### Проверка данных на наличие пропусков и дубликатов

# %%
# функция вывода пропусков и дупликатов
def data_dup_isna(data):
    print('Количество дупликатов')
    display(data.duplicated().sum())
    print('Количество пропусков')
    display(data.isna().sum())

# %%
data_dup_isna(ferma_main)
# Out:
# Количество дупликатов
# 5
# Количество пропусков
# id                                       0
# Удой, кг                                 0
# ЭКЕ (Энергетическая кормовая единица)    0
# Сырой протеин, г                         0
# СПО (Сахаро-протеиновое соотношение)     0
# Порода                                   0
# Тип пастбища                             0
# порода папы_быка                         0
# Жирность,%                               0
# Белок,%                                  0
# Вкус молока                              0
# Возраст                                  0
# dtype: int64

# %%
data_dup_isna(ferma_dad)
# Out:
# Количество дупликатов
# 0
# Количество пропусков
# id          0
# Имя Папы    0
# dtype: int64

# %%
data_dup_isna(cow_buy)
# Out:
# Количество дупликатов
# 4
# Количество пропусков
# Порода                     0
# Тип пастбища               0
# порода папы_быка           0
# Имя_папы                   0
# Текущая_жирность,%         0
# Текущий_уровень_белок,%    0
# Возраст                    0
# dtype: int64

# %% [markdown]
# Пропусков в датафреймах не обнаружено, в ferma_main  - 5 дупликатов и в cow_buy - 4.

# %%
ferma_main[ferma_main.duplicated()]
# Out:
#       id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 629  627      5970                                   14.4              1837
# 630  627      5970                                   14.4              1837
# 631  627      5970                                   14.4              1837
# 632  627      5970                                   14.4              1837
# 633  627      5970                                   14.4              1837
#
#      СПО (Сахаро-протеиновое соотношение)           Порода Тип пастбища  \
# 629                                  0.88  РефлешнСоверинг    Холмистое
# 630                                  0.88  РефлешнСоверинг    Холмистое
# 631                                  0.88  РефлешнСоверинг    Холмистое
# 632                                  0.88  РефлешнСоверинг    Холмистое
# 633                                  0.88  РефлешнСоверинг    Холмистое
#
#     порода папы_быка  Жирность,%  Белок,% Вкус молока      Возраст
# ...

# %% [markdown]
# Строки полностью совпадают влоть до id, который у каждой строки должен быть уникален. <br> Проверим, можно ли удалить данные строки без потери качества датафрейма.

# %%
ferma_dup = ferma_main[ferma_main.duplicated()]

# %%
ferma_dup.shape[0] / ferma_main.shape[0]
# Out:
# 0.007886435331230283

# %% [markdown]
# 8% данных, можно удалить дупликаты:

# %%
ferma_main = ferma_main.drop_duplicates()

# %%
print('Количество строк в ferma_main:', len(ferma_main))
print('Количество строк в ferma_dad:', len(ferma_dad))
# Out:
# Количество строк в ferma_main: 629
# Количество строк в ferma_dad: 629

# %%
cow_buy[cow_buy.duplicated()]
# Out:
#              Порода Тип пастбища порода папы_быка  Имя_папы  \
# 6    Вис Бик Айдиал    холмистое           Айдиал  Геркулес
# 8   РефлешнСоверинг    равнинное          Соверин     Барин
# 14  РефлешнСоверинг    равнинное          Соверин     Барин
# 19  РефлешнСоверинг    равнинное           Айдиал    Буйный
#
#     Текущая_жирность,%  Текущий_уровень_белок,%      Возраст
# 6                 3.58                    3.076  более_2_лет
# 8                 3.59                    3.074  более_2_лет
# 14                3.59                    3.074  более_2_лет
# 19                3.64                    3.074  более_2_лет

# %%
cow_dup = cow_buy[cow_buy.duplicated()]

# %%
cow_dup.shape[0] / cow_buy.shape[0]
# Out:
# 0.2

# %% [markdown]
# Дупликают занимают 20% всего датафрема, не можем удалить дупликаты из cow_buy. <br> Данные в этих строках не идентичны. <br>Тем более это вполне могут быть похожие признаки у разных животных (телята от одних и тех же коровы и бычка)<br>
# Оставим как есть

# %% [markdown]
# ### Изучение и изменение типа данных

# %%
ferma_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629 entries, 0 to 628
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     629 non-null    int64
#  1   Удой, кг                               629 non-null    int64
#  2   ЭКЕ (Энергетическая кормовая единица)  629 non-null    float64
#  3   Сырой протеин, г                       629 non-null    int64
#  4   СПО (Сахаро-протеиновое соотношение)   629 non-null    float64
#  5   Порода                                 629 non-null    object
#  6   Тип пастбища                           629 non-null    object
#  7   порода папы_быка                       629 non-null    object
#  8   Жирность,%                             629 non-null    float64
#  9   Белок,%                                629 non-null    float64
# ...

# %%
cow_buy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Порода                   20 non-null     object
#  1   Тип пастбища             20 non-null     object
#  2   порода папы_быка         20 non-null     object
#  3   Имя_папы                 20 non-null     object
#  4   Текущая_жирность,%       20 non-null     float64
#  5   Текущий_уровень_белок,%  20 non-null     float64
#  6   Возраст                  20 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Изучение категориальных признаков

# %%
def data_unique(data):
    for row in data.columns:
        if data[row].dtype==object:
            print(f'Количество уникальных значений в столбце {row}:')
            print(len(data[row].unique()))
            print(data[row].value_counts())

# %%
def data_style(data):
    for row in data.columns:
        if data[row].dtype==object:
            data[row] = data[row].str.lower()
            data[row] = data[row].str.replace('_', '')
            data[row] = data[row].str.replace('"', '')
            data[row] = data[row].str.replace(' - ', '-')
            data[row] = data[row].str.replace(' ', '')
            data[row] = data[row].str.strip()

# %% [markdown]
# Приведем категориальные данные к единому стилю (нижний регистр, удаление спецсимволов)

# %%
data_style(ferma_main)

# %%
data_style(ferma_dad)

# %%
data_style(cow_buy)

# %% [markdown]
# #### Изучение категориальных признаков ferma_main

# %%
data_unique(ferma_main)
# Out:
# Количество уникальных значений в столбце Порода:
# 2
# висбикайдиал       373
# рефлешнсоверинг    256
# Name: Порода, dtype: int64
# Количество уникальных значений в столбце Тип пастбища:
# 3
# холмистое    351
# равнинное    253
# равнинные     25
# Name: Тип пастбища, dtype: int64
# Количество уникальных значений в столбце порода папы_быка:
# 3
# соверин    311
# айдиал     240
# айдиалл     78
# Name: порода папы_быка, dtype: int64
# Количество уникальных значений в столбце Вкус молока:
# 2
# вкусно      371
# невкусно    258
# Name: Вкус молока, dtype: int64
# Количество уникальных значений в столбце Возраст:
# 2
# более2лет    519
# менее2лет    110
# Name: Возраст, dtype: int64

# %% [markdown]
# В столбце Тип пастбища есть неявные дупликаты равнинное и равнинные. В столбце порода папы_быка - айдиал и айдиалл.

# %%
ferma_main['Тип пастбища'] = ferma_main['Тип пастбища'].str.replace('равнинные', 'равнинное')

# %%
ferma_main['порода папы_быка'] = ferma_main['порода папы_быка'].str.replace('айдиалл', 'айдиал')

# %%
data_unique(ferma_main)
# Out:
# Количество уникальных значений в столбце Порода:
# 2
# висбикайдиал       373
# рефлешнсоверинг    256
# Name: Порода, dtype: int64
# Количество уникальных значений в столбце Тип пастбища:
# 2
# холмистое    351
# равнинное    278
# Name: Тип пастбища, dtype: int64
# Количество уникальных значений в столбце порода папы_быка:
# 2
# айдиал     318
# соверин    311
# Name: порода папы_быка, dtype: int64
# Количество уникальных значений в столбце Вкус молока:
# 2
# вкусно      371
# невкусно    258
# Name: Вкус молока, dtype: int64
# Количество уникальных значений в столбце Возраст:
# 2
# более2лет    519
# менее2лет    110
# Name: Возраст, dtype: int64

# %%
data_unique(ferma_dad)
# Out:
# Количество уникальных значений в столбце Имя Папы:
# 4
# барин       240
# буйный      215
# соловчик    110
# геркулес     64
# Name: Имя Папы, dtype: int64

# %%
data_unique(cow_buy)
# Out:
# Количество уникальных значений в столбце Порода:
# 2
# рефлешнсоверинг    11
# висбикайдиал        9
# Name: Порода, dtype: int64
# Количество уникальных значений в столбце Тип пастбища:
# 2
# равнинное    11
# холмистое     9
# Name: Тип пастбища, dtype: int64
# Количество уникальных значений в столбце порода папы_быка:
# 2
# соверин    12
# айдиал      8
# Name: порода папы_быка, dtype: int64
# Количество уникальных значений в столбце Имя_папы:
# 4
# буйный      8
# геркулес    6
# барин       4
# соловчик    2
# Name: Имя_папы, dtype: int64
# Количество уникальных значений в столбце Возраст:
# 2
# более2лет    15
# менее2лет     5
# Name: Возраст, dtype: int64

# %% [markdown]
# В ходе этапа предобработки данных были удалены дупликаты ferma_main, заменены типы количественных признаков на float. <br>
# Проверены уникальные значения категориальных данных и заменены неявные дупликаты в ferma_main.

# %% [markdown]
# ## Шаг 3.  Исследовательский анализ данных

# %% [markdown]
# ####  Статистический анализ количественных признаков

# %%
def data_hist(data):
    for row in data.columns:
        if data[row].dtype!=object:
            if row == 'id':
                continue
            else:
                plt.hist(data[row], bins = 50)
                plt.xlabel(row)
                plt.ylabel('count')
                plt.title(f'Распределение {row}')
                plt.show()

# %%
data_hist(ferma_main)

# %% [markdown]
# Наблюдатся выброс в районе 45000 в признаке Удой, удалим его. <br>
# Функция распределения признака Белок похожа на нормальное распределение.

# %%
ferma_main[ferma_main['Удой, кг'] > 45000]
# Out:
#     id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 16  17     45616                                   11.5              1675
#
#     СПО (Сахаро-протеиновое соотношение)        Порода Тип пастбища  \
# 16                                  0.93  висбикайдиал    холмистое
#
#    порода папы_быка  Жирность,%  Белок,% Вкус молока    Возраст
# 16           айдиал        3.22    3.076      вкусно  более2лет

# %%
ferma_main = ferma_main[ferma_main['Удой, кг'] < 45000]

# %%
ferma_dad = ferma_dad[ferma_dad.id != 17]

# %%
data_hist(ferma_main)

# %%
data_hist(cow_buy)

# %% [markdown]
# ####  Статистический анализ категориальных признаков

# %%
def data_diagram(data):
    for row in data.columns:
        if data[row].dtype==object:
            data_new = data.pivot_table(index= row, values= 'id', aggfunc= 'count').sort_values(by='id', ascending = True).reset_index()
            fig, ax = plt.subplots()
            ax.pie(data_new['id'], labels=data_new[row], autopct='%1.1f%%')
            plt.title(f'Процентное соотношение {row}')
            plt.show()

# %%
data_diagram(ferma_main)

# %% [markdown]
# Наблюдается преобладание породы висбикайдиал, холмистого типа пастбища. <br> Соотношение породы папы-быка примерно одинаковое - между породами сойверин и айдиал. <br> Вкусного молока больше, чем невкусного, а возраст коров чаще более 2-х лет.

# %%
data_diagram(ferma_dad)

# %% [markdown]
# Наиболее плодовитые папы-быки - барин (38,2%) и буйный  (34,2%).

# %% [markdown]
# Рассмотрены распределения количественных и категориальных признаков в датафреймах. <br>
# В ferma_main:<br>
# Обнаружен и удален выброс в районе 45000 в признаке Удой. <br>
# Функция распределения признака Белок похожа на нормальное распределение, в сотальных признаках отличны от нормального<br>
# Наблюдается преобладание породы висбикайдиал, холмистого типа пастбища. <br> Соотношение породы папы-быка примерно одинаковое - между породами сойверин и айдиал. <br> Вкусного молока больше, чем невкусного, а возраст коров чаще более 2-х лет.<br> Наиболее плодовитые папы-быки - барин (38,2%) и буйный  (34,2%).

# %% [markdown]
# ## Шаг 4.  Корреляционный анализ ferma_main

# %% [markdown]
# #### Взаимосвязь между признаками -коэффициенты корреляции

# %% [markdown]
# Для ненормально распределенных величин используем коэффициент коррекляции Спирмена:

# %%
correlations = ferma_main[['Удой, кг','ЭКЕ (Энергетическая кормовая единица)','Сырой протеин, г','СПО (Сахаро-протеиновое соотношение)','Жирность,%', 'Белок,%']].reset_index(drop=True)
correlations.corr(method= 'spearman')
# Out:
#                                        Удой, кг  \
# Удой, кг                               1.000000
# ЭКЕ (Энергетическая кормовая единица)  0.765144
# Сырой протеин, г                       0.437543
# СПО (Сахаро-протеиновое соотношение)   0.787904
# Жирность,%                             0.688506
# Белок,%                               -0.005701
#
#                                        ЭКЕ (Энергетическая кормовая единица)  \
# Удой, кг                                                            0.765144
# ЭКЕ (Энергетическая кормовая единица)                               1.000000
# Сырой протеин, г                                                    0.384747
# СПО (Сахаро-протеиновое соотношение)                                0.741962
# Жирность,%                                                          0.686973
# Белок,%                                                            -0.013321
#
#                                        Сырой протеин, г  \
# ...

# %% [markdown]
# Удой и СПО имеют сильную взаимосвязь (0,79). Удой и ЭКЕ также имеют сильную корреляцию (0,77). <br>
# Между ЭКЕ и СПО связь с коэффициентом 0,74. <br> Жирность относится с высоким коэффициентом корреляции к признакам: удой (0,69), ЭКЕ (0,69), СПО (0,70).<br> Как правило, о мультиколлинеарности говорят при значении коэффициента корреляции от 0.9 до 0.95 по модулю - в этот раз это не наш случай.

# %% [markdown]
# #### Диаграммы рассеяния для количественных признаков

# %%
pd.plotting.scatter_matrix(correlations, figsize=(15, 15)) 
plt.show()

# %% [markdown]
# ##### Удой, кг

# %%
def scatter_signs(data, col):
    for row in data.columns:
        if data[row].dtype==object:
            print('Диаграмма для параметра:', row)
            sns.scatterplot(data = ferma_main, x = col, y = 'Удой, кг', hue = row)
            plt.show()

# %%
scatter_signs(ferma_main, 'ЭКЕ (Энергетическая кормовая единица)')
# Out:
# Диаграмма для параметра: Порода
# Диаграмма для параметра: Тип пастбища
# Диаграмма для параметра: порода папы_быка
# Диаграмма для параметра: Вкус молока
# Диаграмма для параметра: Возраст

# %% [markdown]
# Наблюдается зависимость Удоя от ЭКЕ, возможно квадратичная, график напоминает ветвь параболы.

# %% [markdown]
# ##### Сырой протеин, г

# %%
scatter_signs(ferma_main, 'Сырой протеин, г')
# Out:
# Диаграмма для параметра: Порода
# Диаграмма для параметра: Тип пастбища
# Диаграмма для параметра: порода папы_быка
# Диаграмма для параметра: Вкус молока
# Диаграмма для параметра: Возраст

# %% [markdown]
# У сырого протеина и удоя не обнаружено линейной зависимости.

# %% [markdown]
# ##### СПО (Сахаро-протеиновое соотношение)

# %%
scatter_signs(ferma_main, 'СПО (Сахаро-протеиновое соотношение)')
# Out:
# Диаграмма для параметра: Порода
# Диаграмма для параметра: Тип пастбища
# Диаграмма для параметра: порода папы_быка
# Диаграмма для параметра: Вкус молока
# Диаграмма для параметра: Возраст

# %% [markdown]
# Между Удоем и СПО нет линейной завимости, есть 2 группы: с высоким СПО (0,93-0,96) и низким (0,84-0,9).

# %% [markdown]
# Удой и СПО имеют сильную взаимосвязь (0,79). Удой и ЭКЕ также имеют сильную корреляцию (0,77). <br>
# Между ЭКЕ и СПО наблюдаем кластеризацию по порогу 0,74. <br> Жирность относится с высоким коэффициентом корреляции к признакам: удой (0,69), ЭКЕ (0,69), СПО (0,70).<br> Как правило, о мультиколлинеарности говорят при значении коэффициента корреляции от 0.9 до 0.95 по модулю - в этот раз это не наш случай. То есть новые признаки нет необходимости вводить.<br>
# Наблюдается линейная зависимость Удоя от ЭКЕ, у сырого протеина и удоя не обнаружено линейной зависимости. Между Удоем и СПО нет линейной завимости, есть 2 группы: с высоким СПО (0,93-0,96) и низким (0,84-0,9).
# Жирность, % и Белок, % не рассмотрены ввиду низкой корреляции по матрице корреляции.

# %% [markdown]
# ## Шаг 5.  Обучение модели линейной регрессии

# %% [markdown]
# #### Первая модель LinearRegression

# %% [markdown]
# В качестве целевого используется признак Удой, кг.<br>
# Жирность,% и Белок,% не рассмотрены ввиду низкой линейной зависимости.<br>

# %%
RANDOM_STATE = 42

X = ferma_main.drop(['Удой, кг',  'Жирность,%', 'Белок,%','Вкус молока'], axis=1)
y = ferma_main['Удой, кг']

X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X, y, random_state= RANDOM_STATE)

сategorial = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст']
quantitative = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)', 'СПО (Сахаро-протеиновое соотношение)']

encoder_1 = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_1 = encoder_1.fit_transform(X_train_1[сategorial])
X_test_ohe_1 = encoder_1.transform(X_test_1[сategorial])

encoder_col_1 = encoder_1.get_feature_names()

scaler_1 = StandardScaler()
X_train_scaled_1 = scaler_1.fit_transform(X_train_1[quantitative])
X_test_scaled_1 = scaler_1.transform(X_test_1[quantitative])

X_train_ohe_1 = pd.DataFrame(X_train_ohe_1, columns= encoder_col_1)
X_test_ohe_1 = pd.DataFrame(X_test_ohe_1, columns= encoder_col_1)
X_train_scaled_1 = pd.DataFrame(X_train_scaled_1, columns= quantitative)
X_test_scaled_1 = pd.DataFrame(X_test_scaled_1, columns= quantitative)

X_train_1 = pd.concat([X_train_ohe_1, X_train_scaled_1], axis=1)
X_test_1 = pd.concat([X_test_ohe_1, X_test_scaled_1], axis=1)

model_lr_1 = LinearRegression()
model_lr_1.fit(X_train_1, y_train_1)
predictions_1 = model_lr_1.predict(X_test_1)

r2_1 = r2_score(y_test_1, predictions_1)

print('R2:', r2_1)
residuals_1 = y_test_1 - predictions_1
# Out:
# R2: 0.784407817341697

# %% [markdown]
# R2=0,78. Чем ближе метрика к единице, тем лучше обобщающая способность модели и тем точнее будут предсказания. Проанализируем остатки:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(bins=10, x= residuals_1)
axes[0].set_title('Распределение остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(x= predictions_1, y= residuals_1)
axes[1].set_title('Анализ дисперсии')
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
plt.show()

# %% [markdown]
# Распределение смещено влево, то есть могут быть даны прогнозы больше истинных значений. <br> Видим, что модель чуть завышает предсказания для низкого удоя. Это нам нежелательно, ведь фермер не хочет рисковать и хочет покупать только подходящих коров.<br>Можно донастроить модель так, чтобы улучшить показатели.

# %% [markdown]
# #### Вторая модель LinearRegression

# %% [markdown]
# Способы, чтобы исключить нелинейность в модели:
# * СПО можно перевести в категориальный бинарный признак. Между Удоем и СПО нет линейной завимости, есть 2 группы: с высоким СПО (0,93-0,96) и низким (0,84-0,9). Выберем за границу 0,92.
# * ЭКЕ и Удой также связаны нелинейно. Нелинейность между ними можно исключить, если ввести новый признак ЭКЕ в квадрате.

# %%
ferma_main_2 = ferma_main[ferma_main.columns]

ferma_main_2.loc[ferma_main_2['СПО (Сахаро-протеиновое соотношение)']<0.92, ['СПО (Сахаро-протеиновое соотношение)']] = 0
ferma_main_2.loc[ferma_main_2['СПО (Сахаро-протеиновое соотношение)']>=0.92, ['СПО (Сахаро-протеиновое соотношение)']] = 1
ferma_main_2['ЭКЕ (Энергетическая кормовая единица)'] = ferma_main_2['ЭКЕ (Энергетическая кормовая единица)']**2

ferma_main_2.head(20)
# Out:
#     id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0    1      5863                                 201.64              1743
# 1    2      5529                                 163.84              2138
# 2    3      5810                                 196.00              1854
# 3    4      5895                                 153.76              2012
# 4    5      5302                                 163.84              1675
# 5    6      5254                                 161.29              1806
# 6    7      5910                                 174.24              1792
# 7    8      6179                                 216.09              1806
# 8    9      6783                                 201.64              1918
# 9   10      5339                                 179.56              1791
# 10  11      5591                                 187.69              1678
# 11  12      6563                                 272.25              2328
# ...

# %%
sns.scatterplot(data=ferma_main_2, y='Удой, кг', x='ЭКЕ (Энергетическая кормовая единица)')
# Out:
# <AxesSubplot:xlabel='ЭКЕ (Энергетическая кормовая единица)', ylabel='Удой, кг'>

# %%
RANDOM_STATE = 42

X = ferma_main_2.drop(['Удой, кг',  'Жирность,%', 'Белок,%', 'Вкус молока'], axis=1)
y = ferma_main_2['Удой, кг']

X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y, random_state= RANDOM_STATE)

сategorial_2 = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)']
quantitative_2 = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)']

encoder_2 = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_2 = encoder_2.fit_transform(X_train_2[сategorial_2])
X_test_ohe_2 = encoder_2.transform(X_test_2[сategorial_2])

encoder_col_2 = encoder_2.get_feature_names()

scaler_2 = StandardScaler()
X_train_scaled_2 = scaler_2.fit_transform(X_train_2[quantitative_2])
X_test_scaled_2 = scaler_2.transform(X_test_2[quantitative_2])

X_train_ohe_2 = pd.DataFrame(X_train_ohe_2, columns= encoder_col_2)
X_test_ohe_2 = pd.DataFrame(X_test_ohe_2, columns= encoder_col_2)
X_train_scaled_2 = pd.DataFrame(X_train_scaled_2, columns= quantitative_2)
X_test_scaled_2 = pd.DataFrame(X_test_scaled_2, columns= quantitative_2)

X_train_2 = pd.concat([X_train_ohe_2, X_train_scaled_2], axis=1)
X_test_2 = pd.concat([X_test_ohe_2, X_test_scaled_2], axis=1)

model_lr_2 = LinearRegression()
model_lr_2.fit(X_train_2, y_train_2)
predictions_2 = model_lr_2.predict(X_test_2)

r2_2 = r2_score(y_test_2, predictions_2)

print('R2:', r2_2)
residuals_2 = y_test_2 - predictions_2
# Out:
# R2: 0.8180879926867501

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(bins=10, x= residuals_2)
axes[0].set_title('Распределение остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(x= predictions_2, y= residuals_2)
axes[1].set_title('Анализ дисперсии')
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
plt.show()

# %% [markdown]
# Метрика R2 выше, то есть модель улучшена. Но распределение также смещено влево, то есть могут быть даны прогнозы больше истинных значений.

# %% [markdown]
# #### Третья модель LinearRegression (новый признак)

# %% [markdown]
# Добавим признак Имя Папы из файла ferma_dad.csv в уже улучшенные данные 2 модели.

# %%
print('Кол-во строк в ferma_main_2:', len(ferma_main_2))
print('Кол-во строк в ferma_dad:', len(ferma_dad))
# Out:
# Кол-во строк в ferma_main_2: 628
# Кол-во строк в ferma_dad: 628

# %%
ferma_main_3 = ferma_main_2.merge(ferma_dad, on= 'id', how= 'left')

# %%
ferma_main_3
# Out:
#       id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0      1      5863                                 201.64              1743
# 1      2      5529                                 163.84              2138
# 2      3      5810                                 196.00              1854
# 3      4      5895                                 153.76              2012
# 4      5      5302                                 163.84              1675
# ..   ...       ...                                    ...               ...
# 623  625      6812                                 237.16              1964
# 624  626      5513                                 166.41              1700
# 625  627      5970                                 207.36              1837
# 626  628      5746                                 190.44              1994
# 627  629      6503                                 262.44              2283
#
# ...

# %%
RANDOM_STATE = 42

X = ferma_main_3.drop(['Удой, кг',  'Жирность,%', 'Белок,%', 'Вкус молока'], axis=1)
y = ferma_main_3['Удой, кг']

X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X, y, random_state= RANDOM_STATE)

сategorial_3 = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст','СПО (Сахаро-протеиновое соотношение)', 'Имя Папы']
quantitative_3 = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)']

encoder_3 = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_3 = encoder_3.fit_transform(X_train_3[сategorial_3])
X_test_ohe_3 = encoder_3.transform(X_test_3[сategorial_3])

encoder_col_3 = encoder_3.get_feature_names()

scaler_3 = StandardScaler()
X_train_scaled_3 = scaler_3.fit_transform(X_train_3[quantitative_3])
X_test_scaled_3 = scaler_3.transform(X_test_3[quantitative_3])

X_train_ohe_3 = pd.DataFrame(X_train_ohe_3, columns= encoder_col_3)
X_test_ohe_3 = pd.DataFrame(X_test_ohe_3, columns= encoder_col_3)
X_train_scaled_3 = pd.DataFrame(X_train_scaled_3, columns= quantitative_3)
X_test_scaled_3 = pd.DataFrame(X_test_scaled_3, columns= quantitative_3)

X_train_3 = pd.concat([X_train_ohe_3, X_train_scaled_3], axis=1)
X_test_3 = pd.concat([X_test_ohe_3, X_test_scaled_3], axis=1)

model_lr_3 = LinearRegression()
model_lr_3.fit(X_train_3, y_train_3)
predictions_3 = model_lr_3.predict(X_test_3)

r2_3 = r2_score(y_test_3, predictions_3)

print('R2:', r2_3)
residuals_3 = y_test_3 - predictions_3
# Out:
# R2: 0.8247542745210407

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
axes[0].hist(bins=10, x= residuals_3)
axes[0].set_title('Распределение остатков')
axes[0].set_xlabel('Остатки')

axes[1].scatter(x= predictions_3, y= residuals_3)
axes[1].set_title('Анализ дисперсии')
axes[1].set_xlabel('Предсказания модели')
axes[1].set_ylabel('Остатки')
plt.show()

# %% [markdown]
# Метрика R2 выше, то есть модель улучшена. Распределение остатков более симметрично.

# %% [markdown]
# #### Качество моделей линейной регрессии, их R² и остатки.

# %% [markdown]
# Согласно коэффициенту  R2 и распределению остатков 3-я модель показывает наилучшие результаты.

# %% [markdown]
# #### MSE, MAE, RMSE

# %%
mse_1 = mean_squared_error(y_test_1, predictions_1)
mse_2 = mean_squared_error(y_test_2, predictions_2)
mse_3 = mean_squared_error(y_test_3, predictions_3)
print('MSE 1 модели:', mse_1)
print('MSE 2 модели:', mse_2)
print('MSE 3 модели:', mse_3)
# Out:
# MSE 1 модели: 43887.01500966046
# MSE 2 модели: 37030.91131113695
# MSE 3 модели: 35673.88988618193

# %%
mae_1 = mean_absolute_error(y_test_1, predictions_1)
mae_2 = mean_absolute_error(y_test_2, predictions_2)
mae_3 = mean_absolute_error(y_test_3, predictions_3)
print('МАЕ 1 модели:', mae_1)
print('МАЕ 2 модели:', mae_2)
print('МАЕ 3 модели:', mae_3)
# Out:
# МАЕ 1 модели: 164.24194463474916
# МАЕ 2 модели: 149.03965222364596
# МАЕ 3 модели: 146.1630244536231

# %%
rmse_1 = mean_squared_error(y_test_1, predictions_1, squared= False)
rmse_2 = mean_squared_error(y_test_2, predictions_2, squared= False)
rmse_3 = mean_squared_error(y_test_3, predictions_3, squared= False)
print('RMSE 1 модели:', rmse_1)
print('RMSE 2 модели:', rmse_2)
print('RMSE 3 модели:', rmse_3)
# Out:
# RMSE 1 модели: 209.4922791170607
# RMSE 2 модели: 192.43417396901452
# RMSE 3 модели: 188.87532895055915

# %%
print('95% доверительный интервал 1 модели =', st.norm.interval(0.95, loc=np.mean(predictions_1), scale=st.sem(predictions_1)))
print('95% доверительный интервал 2 модели =', st.norm.interval(0.95, loc=np.mean(predictions_2), scale=st.sem(predictions_2)))
print('95% доверительный интервал 3 модели =', st.norm.interval(0.95, loc=np.mean(predictions_3), scale=st.sem(predictions_3)))
# Out:
# 95% доверительный интервал 1 модели = (6106.009965598841, 6228.04870872839)
# 95% доверительный интервал 2 модели = (6103.099544882739, 6228.9581532991515)
# 95% доверительный интервал 3 модели = (6092.340075854288, 6221.3750700583805)

# %% [markdown]
# По метрикам MSE, MAE, RMSE у 3 модели наименьшее отклонение, R2 также самый высокий у модели под номером 3. <br> Доверительный интервал 3 модели наилучший.

# %% [markdown]
# #### Прогноз удоя по лучшей модели

# %% [markdown]
# Добавим недостающие признаки ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г и СПО (Сахаро-протеиновое соотношение): из датасета ferma_main.csv средние значения каждого из признаков, увеличенные на 5%.

# %%
cow_buy_new = cow_buy[cow_buy.columns]

# %%
cow_buy_new['ЭКЕ (Энергетическая кормовая единица)'] = ferma_main['ЭКЕ (Энергетическая кормовая единица)'].mean()*1.05
cow_buy_new['СПО (Сахаро-протеиновое соотношение)'] = ferma_main['СПО (Сахаро-протеиновое соотношение)'].mean()*1.05
cow_buy_new['Сырой протеин, г'] = ferma_main['Сырой протеин, г'].mean()*1.05

# %%
cow_buy_new.head(20)
# Out:
#              Порода Тип пастбища порода папы_быка  Имя_папы  \
# 0      висбикайдиал    холмистое           айдиал  геркулес
# 1      висбикайдиал    равнинное          соверин    буйный
# 2   рефлешнсоверинг    равнинное          соверин     барин
# 3   рефлешнсоверинг    холмистое           айдиал    буйный
# 4   рефлешнсоверинг    равнинное           айдиал    буйный
# 5   рефлешнсоверинг    равнинное          соверин  геркулес
# 6      висбикайдиал    холмистое           айдиал  геркулес
# 7      висбикайдиал    равнинное          соверин    буйный
# 8   рефлешнсоверинг    равнинное          соверин     барин
# 9   рефлешнсоверинг    холмистое           айдиал    буйный
# 10     висбикайдиал    холмистое          соверин  соловчик
# 11  рефлешнсоверинг    равнинное          соверин  геркулес
# 12     висбикайдиал    холмистое           айдиал  геркулес
# 13     висбикайдиал    холмистое          соверин     барин
# 14  рефлешнсоверинг    равнинное          соверин     барин
# ...

# %%
cow_buy_new.loc[cow_buy_new['СПО (Сахаро-протеиновое соотношение)']<0.92, ['СПО (Сахаро-протеиновое соотношение)']] = 0
cow_buy_new.loc[cow_buy_new['СПО (Сахаро-протеиновое соотношение)']>=0.92, ['СПО (Сахаро-протеиновое соотношение)']] = 1
cow_buy_new['ЭКЕ (Энергетическая кормовая единица)'] = cow_buy_new['ЭКЕ (Энергетическая кормовая единица)']**2

# %%
print('Количество строк в ferma_main:', len(ferma_main))
print('Количество строк в ferma_dad:', len(ferma_dad))
print('Количество строк в cow_buy:', len(cow_buy))
# Out:
# Количество строк в ferma_main: 628
# Количество строк в ferma_dad: 628
# Количество строк в cow_buy: 20

# %%
сategorial_names = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)', 'Имя_папы']
quantitative_names = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)']

cow_buy_new_ohe = encoder_3.transform(cow_buy_new[сategorial_names])

encoder_col_cow = encoder_3.get_feature_names()

cow_buy_new_scaled = scaler_3.transform(cow_buy_new[quantitative_names])

X_test_ohe = pd.DataFrame(cow_buy_new_ohe, columns=encoder_col_cow)
X_test_scaled = pd.DataFrame(cow_buy_new_scaled, columns=quantitative_names)
X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)

predictions_cow_buy = model_lr_3.predict(X_test)
predictions_cow_buy
# Out:
# array([6609.91929681, 6378.71102836, 6283.99977532, 6593.08937654,
#        6542.14606633, 6425.38021759, 6609.91929681, 6571.25973712,
#        6283.99977532, 6400.54066779, 6344.70785976, 6617.92892634,
#        6609.91929681, 6127.4747423 , 6283.99977532, 6593.08937654,
#        6344.70785976, 6425.38021759, 6571.25973712, 6542.14606633])

# %%
cow_buy_new['Удой, кг'] = predictions_cow_buy

# %%
cow_buy_new
# Out:
#              Порода Тип пастбища порода папы_быка  Имя_папы  \
# 0      висбикайдиал    холмистое           айдиал  геркулес
# 1      висбикайдиал    равнинное          соверин    буйный
# 2   рефлешнсоверинг    равнинное          соверин     барин
# 3   рефлешнсоверинг    холмистое           айдиал    буйный
# 4   рефлешнсоверинг    равнинное           айдиал    буйный
# 5   рефлешнсоверинг    равнинное          соверин  геркулес
# 6      висбикайдиал    холмистое           айдиал  геркулес
# 7      висбикайдиал    равнинное          соверин    буйный
# 8   рефлешнсоверинг    равнинное          соверин     барин
# 9   рефлешнсоверинг    холмистое           айдиал    буйный
# 10     висбикайдиал    холмистое          соверин  соловчик
# 11  рефлешнсоверинг    равнинное          соверин  геркулес
# 12     висбикайдиал    холмистое           айдиал  геркулес
# 13     висбикайдиал    холмистое          соверин     барин
# 14  рефлешнсоверинг    равнинное          соверин     барин
# ...

# %% [markdown]
# ## Шаг 6.  Обучение модели логистической регрессии

# %% [markdown]
# #### Обучение логистической модели

# %% [markdown]
# Обучим модель LogisticRegression.Используем в качестве целевого признак Вкус молока.Рассчитаем метрики accuracy, recall, precision и построим матрицу ошибок.

# %%
ferma_main_2['Вкус молока'] = ferma_main_2['Вкус молока'].apply(lambda x: 1 if x == 'вкусно' else 0)
ferma_main_2['Вкус молока'] = ferma_main_2['Вкус молока'].astype(float)

# %%
ferma_main_2
# Out:
#       id  Удой, кг  ЭКЕ (Энергетическая кормовая единица)  Сырой протеин, г  \
# 0      1      5863                                 201.64              1743
# 1      2      5529                                 163.84              2138
# 2      3      5810                                 196.00              1854
# 3      4      5895                                 153.76              2012
# 4      5      5302                                 163.84              1675
# ..   ...       ...                                    ...               ...
# 624  625      6812                                 237.16              1964
# 625  626      5513                                 166.41              1700
# 626  627      5970                                 207.36              1837
# 627  628      5746                                 190.44              1994
# 628  629      6503                                 262.44              2283
#
# ...

# %%
RANDOM_STATE = 42

X_l = ferma_main_2.drop(['Вкус молока', 'Удой, кг'], axis=1)
y_l = ferma_main_2['Вкус молока']

X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l, y_l, random_state= RANDOM_STATE)

сategorial_names = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)']
quantitative_names = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)', 'Жирность,%', 'Белок,%']

encoder_l = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_l = encoder_l.fit_transform(X_train_l[сategorial_names])
X_test_ohe_l = encoder_l.transform(X_test_l[сategorial_names])

encoder_col_names_l = encoder_l.get_feature_names()

scaler_l = StandardScaler()
X_train_scaled_l = scaler_l.fit_transform(X_train_l[quantitative_names])
X_test_scaled_l = scaler_l.transform(X_test_l[quantitative_names])

X_train_ohe_l = pd.DataFrame(X_train_ohe_l, columns= encoder_col_names_l)
X_test_ohe_l = pd.DataFrame(X_test_ohe_l, columns= encoder_col_names_l)

X_train_scaled_l = pd.DataFrame(X_train_scaled_l, columns= quantitative_names)
X_test_scaled_l = pd.DataFrame(X_test_scaled_l, columns= quantitative_names)

X_train_l = pd.concat([X_train_ohe_l, X_train_scaled_l], axis=1)
X_test_l = pd.concat([X_test_ohe_l, X_test_scaled_l], axis=1)

clf = OneVsRestClassifier(LogisticRegression())
clf = clf.fit(X_train_l, y_train_l)

y_l_pred = clf.predict(X_test_l)

# %%
acc = accuracy_score(y_test_l, y_l_pred)
rec = recall_score(y_test_l, y_l_pred)
prec = precision_score(y_test_l, y_l_pred)

print('Accuracy: ', acc)
print('Recall:' , rec)
print("Precision:" , prec)
# Out:
# Accuracy:  0.6242038216560509
# Recall: 0.8522727272727273
# Precision: 0.6198347107438017

# %%
cm = confusion_matrix(y_test_l, y_l_pred)
sns.heatmap(cm, annot= True)
plt.ylabel('Значения')
plt.xlabel('Предсказания')
plt.title('Матрица ошибок')
# Out:
# Text(0.5, 1.0, 'Матрица ошибок')

# %% [markdown]
# #### Анализ логистической модели

# %% [markdown]
# Модель предсказала, что у 75 коров действительно вкусное молоко (86% по метрике recall). <br> Но в нашем случае куда важнее снизить количество ошибочных предсказаний на вкусное молоко - ошибок первого рода, чтобы не разочаровать заказчика. Таким образом необходимо улучшить метрику Precision.<br>
# Сведем критичную ошибку к нулю: для этого изменим порог принадлежности к классам.

# %%
y_proba = clf.predict_proba(X_test_l)[:,1]

data = pd.DataFrame(zip(y_test_l, y_proba),
             columns = ['y_valid', 'y_proba']).sort_values(by='y_proba',ascending=False)

print(data.head())
# Out:
#      y_valid   y_proba
# 85       1.0  0.839956
# 66       1.0  0.836504
# 110      1.0  0.830874
# 51       1.0  0.824231
# 146      1.0  0.821701

# %%
thresholds = [round(i,2) for i in np.linspace(0.70,0.85,num = 15,endpoint=False)]
print(thresholds)
# Out:
# [0.7, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8, 0.81, 0.82, 0.83, 0.84]

# %%
columns = []

for i in thresholds:
    columns.append('y_pred_'+str(i))
    data['y_pred_'+str(i)] = data['y_proba'].apply(lambda y_proba: 1 if y_proba >=i else 0)

limit = []
limit = pd.DataFrame(columns=['Порог', 'Precision'])

col = 0
for k in data.columns[2:]:
    prec = precision_score(data['y_valid'],data[k])
    limit.loc[col] = [k, prec]
    col = col+1
limit
# Out:
#           Порог  Precision
# 0    y_pred_0.7   0.860465
# 1   y_pred_0.71   0.871795
# 2   y_pred_0.72   0.868421
# 3   y_pred_0.73   0.852941
# 4   y_pred_0.74   0.814815
# 5   y_pred_0.75   0.869565
# 6   y_pred_0.76   0.833333
# 7   y_pred_0.77   0.882353
# 8   y_pred_0.78   0.846154
# 9   y_pred_0.79   0.800000
# 10   y_pred_0.8   1.000000
# 11  y_pred_0.81   1.000000
# 12  y_pred_0.82   1.000000
# 13  y_pred_0.83   1.000000
# 14  y_pred_0.84   0.000000

# %% [markdown]
# Примем за новый порог 0,8.

# %%
LIMIT = 0.8
RANDOM_STATE = 42

X_l = ferma_main_2.drop(['Вкус молока', 'Удой, кг'], axis=1)
y_l = ferma_main_2['Вкус молока']

X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l, y_l, random_state= RANDOM_STATE)

сategorial_names = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)']
quantitative_names = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)', 'Жирность,%', 'Белок,%']

encoder_l = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_l = encoder_l.fit_transform(X_train_l[сategorial_names])
X_test_ohe_l = encoder_l.transform(X_test_l[сategorial_names])

encoder_col_names_l = encoder_l.get_feature_names()

scaler_l = StandardScaler()
X_train_scaled_l = scaler_l.fit_transform(X_train_l[quantitative_names])
X_test_scaled_l = scaler_l.transform(X_test_l[quantitative_names])

X_train_ohe_l = pd.DataFrame(X_train_ohe_l, columns= encoder_col_names_l)
X_test_ohe_l = pd.DataFrame(X_test_ohe_l, columns= encoder_col_names_l)

X_train_scaled_l = pd.DataFrame(X_train_scaled_l, columns= quantitative_names)
X_test_scaled_l = pd.DataFrame(X_test_scaled_l, columns= quantitative_names)

X_train_l = pd.concat([X_train_ohe_l, X_train_scaled_l], axis=1)
X_test_l = pd.concat([X_test_ohe_l, X_test_scaled_l], axis=1)

clf = OneVsRestClassifier(LogisticRegression())
clf = clf.fit(X_train_l, y_train_l)

y_l_pred = clf.predict(X_test_l)
y_l_pred = np.where(clf.predict_proba(X_test_l)[:,1] > LIMIT, 1, 0)

# %%
acc = accuracy_score(y_test_l, y_l_pred)
rec = recall_score(y_test_l, y_l_pred)
prec = precision_score(y_test_l, y_l_pred)

print('Accuracy: ', acc)
print('Recall:' , rec)
print("Precision:" , prec)
# Out:
# Accuracy:  0.4840764331210191
# Recall: 0.07954545454545454
# Precision: 1.0

# %% [markdown]
# Precision стало равно 1, но остальные характеристики сильно упали. Попробуем порог в 0,7.

# %%
LIMIT = 0.7
RANDOM_STATE = 42

X_l = ferma_main_2.drop(['Вкус молока', 'Удой, кг'], axis=1)
y_l = ferma_main_2['Вкус молока']

X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l, y_l, random_state= RANDOM_STATE)

сategorial_names = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)']
quantitative_names = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)', 'Жирность,%', 'Белок,%']

encoder_l = OneHotEncoder(drop='first', sparse= False)
X_train_ohe_l = encoder_l.fit_transform(X_train_l[сategorial_names])
X_test_ohe_l = encoder_l.transform(X_test_l[сategorial_names])

encoder_col_names_l = encoder_l.get_feature_names()

scaler_l = StandardScaler()
X_train_scaled_l = scaler_l.fit_transform(X_train_l[quantitative_names])
X_test_scaled_l = scaler_l.transform(X_test_l[quantitative_names])

X_train_ohe_l = pd.DataFrame(X_train_ohe_l, columns= encoder_col_names_l)
X_test_ohe_l = pd.DataFrame(X_test_ohe_l, columns= encoder_col_names_l)

X_train_scaled_l = pd.DataFrame(X_train_scaled_l, columns= quantitative_names)
X_test_scaled_l = pd.DataFrame(X_test_scaled_l, columns= quantitative_names)

X_train_l = pd.concat([X_train_ohe_l, X_train_scaled_l], axis=1)
X_test_l = pd.concat([X_test_ohe_l, X_test_scaled_l], axis=1)

clf = OneVsRestClassifier(LogisticRegression())
clf = clf.fit(X_train_l, y_train_l)

y_l_pred = clf.predict(X_test_l)
y_l_pred = np.where(clf.predict_proba(X_test_l)[:,1] > LIMIT, 1, 0)

# %%
acc = accuracy_score(y_test_l, y_l_pred)
rec = recall_score(y_test_l, y_l_pred)
prec = precision_score(y_test_l, y_l_pred)

print('Accuracy: ', acc)
print('Recall:' , rec)
print("Precision:" , prec)
# Out:
# Accuracy:  0.6369426751592356
# Recall: 0.42045454545454547
# Precision: 0.8604651162790697

# %% [markdown]
# Снизили количество ошибок помощью повышения Precision, но оставили адекватные значения Accuracy и Recall.

# %% [markdown]
# #### Прогноз вкуса молока коров

# %% [markdown]
# С помощью обученной модели спрогнозируем вкус молока коров, которых фермер хочет купить.

# %%
cow_buy_new = cow_buy_new.rename(columns={'Текущая_жирность,%': 'Жирность,%', 'Имя_папы': 'Имя Папы', 'Текущий_уровень_белок,%': 'Белок,%'})

# %%
cow_buy_new
# Out:
#              Порода Тип пастбища порода папы_быка  Имя Папы  Жирность,%  \
# 0      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 1      висбикайдиал    равнинное          соверин    буйный        3.54
# 2   рефлешнсоверинг    равнинное          соверин     барин        3.59
# 3   рефлешнсоверинг    холмистое           айдиал    буйный        3.40
# 4   рефлешнсоверинг    равнинное           айдиал    буйный        3.64
# 5   рефлешнсоверинг    равнинное          соверин  геркулес        3.63
# 6      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 7      висбикайдиал    равнинное          соверин    буйный        3.57
# 8   рефлешнсоверинг    равнинное          соверин     барин        3.59
# 9   рефлешнсоверинг    холмистое           айдиал    буйный        3.40
# 10     висбикайдиал    холмистое          соверин  соловчик        3.73
# 11  рефлешнсоверинг    равнинное          соверин  геркулес        3.73
# ...

# %%
RANDOM_STATE = 42
LIMIT = 0.7

X_l = ferma_main_2.drop(['Вкус молока', 'Удой, кг'], axis=1)
y_l = ferma_main_2['Вкус молока']

X_l2 = cow_buy_new.drop(['Удой, кг'], axis=1)

X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l, y_l, random_state= RANDOM_STATE)

сategorial_names = ['Порода', 'Тип пастбища', 'порода папы_быка', 'Возраст', 'СПО (Сахаро-протеиновое соотношение)']
quantitative_names = ['Сырой протеин, г', 'ЭКЕ (Энергетическая кормовая единица)', 'Жирность,%', 'Белок,%']

X_test_ohe_l = encoder_l.transform(X_test_l[сategorial_names])

X_test_scaled_l = scaler_l.transform(X_test_l[quantitative_names])

X_test_ohe_l = pd.DataFrame(X_test_ohe_l, columns= encoder_col_names_l)
X_test_scaled_l = pd.DataFrame(X_test_scaled_l, columns= quantitative_names)

X_l2_ohe = encoder_l.transform(X_l2[сategorial_names])
X_l2_scaled = scaler_l.transform(X_l2[quantitative_names])

X_l2_ohe = pd.DataFrame(X_l2_ohe, columns= encoder_col_names_l)
X_l2_scaled = pd.DataFrame(X_l2_scaled, columns= quantitative_names)
X_l2 = pd.concat([X_l2_ohe, X_l2_scaled], axis=1)

taste_pred = np.where(clf.predict_proba(X_l2)[:,1] > LIMIT, 1, 0)

# %%
tastes = []
for taste in taste_pred:
    if taste == 1:
        tastes.append('вкусно')
    else:
        tastes.append('не вкусно')
        
cow_buy_new['Вкус молока'] = tastes
cow_buy_new
# Out:
#              Порода Тип пастбища порода папы_быка  Имя Папы  Жирность,%  \
# 0      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 1      висбикайдиал    равнинное          соверин    буйный        3.54
# 2   рефлешнсоверинг    равнинное          соверин     барин        3.59
# 3   рефлешнсоверинг    холмистое           айдиал    буйный        3.40
# 4   рефлешнсоверинг    равнинное           айдиал    буйный        3.64
# 5   рефлешнсоверинг    равнинное          соверин  геркулес        3.63
# 6      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 7      висбикайдиал    равнинное          соверин    буйный        3.57
# 8   рефлешнсоверинг    равнинное          соверин     барин        3.59
# 9   рефлешнсоверинг    холмистое           айдиал    буйный        3.40
# 10     висбикайдиал    холмистое          соверин  соловчик        3.73
# 11  рефлешнсоверинг    равнинное          соверин  геркулес        3.73
# ...

# %% [markdown]
# ## Шаг 7.  Итоговые выводы

# %% [markdown]
# #### Отбор коров, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко.

# %%
cow_buy_new[(cow_buy_new['Удой, кг'] >= 6000)&(cow_buy_new['Вкус молока'] != 'не вкусно')]
# Out:
#              Порода Тип пастбища порода папы_быка  Имя Папы  Жирность,%  \
# 0      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 6      висбикайдиал    холмистое           айдиал  геркулес        3.58
# 9   рефлешнсоверинг    холмистое           айдиал    буйный        3.40
# 16     висбикайдиал    холмистое          соверин  соловчик        3.73
#
#     Белок,%    Возраст  ЭКЕ (Энергетическая кормовая единица)  \
# 0     3.076  более2лет                             233.361138
# 6     3.076  более2лет                             233.361138
# 9     3.079  менее2лет                             233.361138
# 16    3.079  более2лет                             233.361138
#
#     СПО (Сахаро-протеиновое соотношение)  Сырой протеин, г     Удой, кг  \
# 0                                    1.0       2019.947532  6609.919297
# 6                                    1.0       2019.947532  6609.919297
# 9                                    1.0       2019.947532  6400.540668
# ...

# %% [markdown]
# Коров, удовлетворяющих требованиям - 4.

# %% [markdown]
# #### Результаты работы моделей для фермера

# %% [markdown]
# * На первом этапе были загружены данные.
# * В ходе этапа предобработки данных были удалены дупликаты ferma_main, заменены типы количественных признаков на float. <br>
# Проверены уникальные значения категориальных данных и заменены неявные дупликаты в ferma_main.
# * 3 этап - исследовательский анализ данных.
# Рассмотрены распределения количественных и категориальных признаков в датафреймах.
# В ferma_main:<br>
# Обнаружен и удален выброс в районе 45000 в признаке Удой.<br>
# Функция распределения признака Белок похожа на нормальное распределение.<br>
# Наблюдается преобладание породы висбикайдиал, холмистого типа пастбища.<br>
# Соотношение породы папы-быка примерно одинаковое - между породами сойверин и айдиал.<br>
# Вкусного молока больше, чем невкусного, а возраст коров чаще более 2-х лет.<br>
# Наиболее плодовитые папы-быки - барин (38,2%) и буйный (34,2%).<br>
# * На 4 этапе проведен корреляционный анализ данных.
# Удой и СПО имеют сильную взаимосвязь (0,79). Удой и ЭКЕ также имеют сильную корреляцию (0,77). <br>
# Между ЭКЕ и СПО связь с коэффициентом 0,74. <br> Жирность относится с высоким коэффициентом корреляции к признакам: удой (0,69), ЭКЕ (0,69), СПО (0,70).<br> Как правило, о мультиколлинеарности говорят при значении коэффициента корреляции от 0.9 до 0.95 по модулю - в этот раз это не наш случай. <br>
# Наблюдается линейная зависимость Удоя от ЭКЕ, у сырого протеина и удоя не обнаружено линейной зависимости. Между Удоем и СПО нет линейной завимости, есть 2 группы: с высоким СПО (0,93-0,96) и низким (0,84-0,9).
# Жирность, % и Белок, % не рассмотрены ввиду низкой корреляции по матрице корреляции.
# * В 5 этапе построена линейная модель с целевым признаком 'Удой' в 3-х вариантах:
#  - первая модель - первоначальная,
#  - вторая модель - СПО переведена в категориальный бинарный признак, ЭКЕ в квадрате,
#  - третья модель - с добавленным признаком Имя папы. <br>
#  По метрикам MSE, MAE, RMSE у 3 модели наименьшее отклонение, R2 также самый высокий у модели под номером 3. <br> Доверительный интервал 3 модели больше, чем у других. По 3 модели спрогнозирован удой коров в cow_buy.
# * В 6 разделе обучена логистическая модель с целевым признаком Вкус молока.
# Также были построены матрицы корреляции и рассчитаны основные метрики модели (Accuracy, Recall, Precision). <br>
# В нашем случае куда важнее снизить количество ошибочных предсказаний на вкусное молоко - ошибок первого рода, чтобы не разочаровать заказчика. Таким образом была необходимость улучшить метрику Precision, для этого изменили порог принадлежности к классам.<br>
# После этого с откорректированным порогом были получены предсказания вкуса молока в cow_buy.
# * В заключение отобраны коровы, для которых спрогнозирован удой более 6000 килограммов в год и вкусное молоко - 4 коровы.
# В целях развития бизнеса, чтобы продать клиенту больше коров - стоит либо опираться на один признак из двух, либо понизить требования.
# * Для улучшения качества модели можно увеличить количество выборки для обучения модели, сменить данные ferma_main  на более близкие по зависимостям к cow_buy, а также ввести новые входящие признаки для объяснения изменчивости.
